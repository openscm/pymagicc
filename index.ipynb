# %% [markdown]
# # Pymagicc Usage Examples

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 16, 9

# %%
import pymagicc

# %%
from pymagicc import rcp3pd, rcp45, rcp6, rcp85, scenarios

# %% [markdown]
# ## Scenarios
#
# The four RCP scenarios are already preloaded as DataFrames in pyhector. They contain the following emissions:

# %%
rcp3pd["WORLD"].columns
# Out:
# Index(['FossilCO2', 'OtherCO2', 'CH4', 'N2O', 'SOx', 'CO', 'NMVOC', 'NOx',
#        'BC', 'OC', 'NH3', 'CF4', 'C2F6', 'C6F14', 'HFC23', 'HFC32', 'HFC43-10',
#        'HFC125', 'HFC134a', 'HFC143a', 'HFC227ea', 'HFC245fa', 'SF6'],
#       dtype='object')

# %% [markdown]
# They are split up in regions:

# %%
rcp3pd.keys()
# Out:
# dict_keys(['WORLD', 'R5OECD', 'R5REF', 'R5ASIA', 'R5MAF', 'R5LAM', 'BUNKERS'])

# %%
rcp3pd["WORLD"].head()
# Out:
#        FossilCO2  OtherCO2       CH4     N2O      SOx         CO     NMVOC  \
# YEARS
# 2000       6.735    1.1488  300.2070  7.4567  53.8413  1068.0009  210.6230
# 2001       6.896    1.1320  303.4093  7.5029  54.4192  1066.7447  211.5938
# 2002       6.949    1.2317  306.5787  7.5487  54.9960  1065.4692  212.5632
# 2003       7.286    1.2256  309.7165  7.5942  55.5716  1064.1742  213.5311
# 2004       7.672    1.2428  312.8241  7.6394  56.1461  1062.8596  214.4977
#
#            NOx      BC       OC   ...     C6F14    HFC23   HFC32  HFC43-10  \
# YEARS                             ...
# 2000   38.1623  7.8048  35.5434   ...    0.4624  10.3949  4.0000    0.0000
# 2001   38.2888  7.8946  35.7143   ...    0.4651  10.4328  5.3987    0.6470
# 2002   38.4153  7.9841  35.8846   ...    0.4058  10.4708  6.7974    1.2941
# 2003   38.5418  8.0734  36.0543   ...    0.3939  10.5083  8.1961    1.9411
# 2004   38.6683  8.1624  36.2233   ...    0.4062  10.5455  9.5948    2.5881
#
#         HFC125   HFC134a  HFC143a  HFC227ea  HFC245fa     SF6
# YEARS
# 2000    8.5381   75.0394   6.2341     1.951   17.9257  5.5382
# 2001    9.0301   84.0409   7.4947     1.645   19.7183  5.6990
# 2002    9.8853   94.7162   8.7389     2.508   21.5109  5.8596
# 2003   12.0788  101.4157   9.9776     3.341   23.3034  6.0202
# 2004   12.5074  113.9297  11.2136     4.269   25.0960  6.1806
#
# [5 rows x 23 columns]

# %% [markdown]
# They have the following units:

# %%
pymagicc.units
# Out:
# {'BC': 'Mt',
#  'C2F6': 'kt',
#  'C6F14': 'kt',
#  'CF4': 'kt',
#  'CH4': 'MtCH4',
#  'CO': 'MtCO',
#  'FossilCO2': 'GtC',
#  'HFC125': 'kt',
#  'HFC134a': 'kt',
#  'HFC143a': 'kt',
#  'HFC227ea': 'kt',
#  'HFC23': 'kt',
#  'HFC245fa': 'kt',
#  'HFC32': 'kt',
#  'HFC43-10': 'kt',
#  'N2O': 'MtN2O-N',
#  'NH3': 'MtN',
#  'NMVOC': 'Mt',
#  'NOx': 'MtN',
#  'OC': 'Mt',
#  'OtherCO2': 'GtC',
#  'SF6': 'kt',
#  'SOx': 'MtS',
#  'YEARS': 'Yrs'}

# %% [markdown]
# A plot of four categories in RCP3PD

# %%
emissions = ["FossilCO2", "OtherCO2", "CH4", "N2O"]
rcp3pd["WORLD"][emissions].loc[:2150].plot(subplots=True);
plt.suptitle("RCP3PD");

# %% [markdown]
# Fossil fuel emissions for the four RCP scenarios.

# %%
for name, scen in scenarios.items():
    scen["WORLD"].loc[:2100].FossilCO2.plot(label=name)
plt.legend()
plt.ylabel(pymagicc.units["FossilCO2"])
plt.title("Fossil Fuel emissions (CO₂) for RCP scenarios");

# %% [markdown]
# ## Running MAGICC
#
# A single `pymagicc` run doesn't take long and returns a Pandas Panel with output variables as well as the used parameters.

# %%
# %time results = pymagicc.run(rcp3pd)
# Out:
# CPU times: user 396 ms, sys: 12 ms, total: 408 ms
# Wall time: 930 ms

# %%
for name, scen in scenarios.items():
    results = pymagicc.run(scen)
    temp = results["SURFACE_TEMP"].GLOBAL.loc[1850:] - results["SURFACE_TEMP"].GLOBAL.loc[1850:1900].mean()
    temp.plot(label=name)
plt.legend()
plt.title("Global Mean Temperature Projection")
plt.ylabel("°C over pre-industrial (1850-1900 mean)");

# %% [markdown]
# The default parameters are the ones that were used to produce the RCP GHG concentrations (see also http://live.magicc.org/). Of course it's easy to change them.

# %%
low = pymagicc.run(rcp45, core_climatesensitivity=1.5)
default = pymagicc.run(rcp45, core_climatesensitivity=3)
high = pymagicc.run(rcp45, core_climatesensitivity=4.5)

# %%
sel = slice(1850, 2100)
plt.fill_between(low["SURFACE_TEMP"].loc[sel].index,
                 low["SURFACE_TEMP"].loc[sel].GLOBAL,
                 high["SURFACE_TEMP"].loc[sel].GLOBAL,
                 color="lightgray")
default["SURFACE_TEMP"].loc[sel].GLOBAL.plot()
plt.title("RCP 4.5 with equilibrium climate sensitivity set to 1.5, 3, and 4.5")
plt.ylabel("°C");
