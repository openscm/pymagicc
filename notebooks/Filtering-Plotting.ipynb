# %% [markdown]
# # Filtering and plotting
#
# Here we provide a quick example of how to filter and plot with your data, making the most of the capability provided by pyam's IamDataFrame.

# %%
# NBVAL_IGNORE_OUTPUT
from pymagicc import MAGICC6
from pymagicc import rcp26

import matplotlib.pyplot as plt

plt.style.use("bmh")
# Out:
# pyam - INFO: Running in a notebook, setting `pyam` logging level to `logging.INFO` and adding stderr handler

# %% [markdown]
# Run MAGICC6.

# %%
with MAGICC6() as magicc:
    results = magicc.run(rcp26)

# %%
# NBVAL_IGNORE_OUTPUT
# Note that row ordering may vary
results.head()
# Out:
# time                                                                                                                  1765-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                                   0.0
#                                                                                      World|Northern Hemisphere|Ocean         0.0
#                                                                                      World|Northern Hemisphere|Land          0.0
#                                                                                      World|Southern Hemisphere|Ocean         0.0
#                                                                                      World|Southern Hemisphere|Land          0.0
#
# time                                                                                                                  1766-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.030727
#                                                                                      World|Northern Hemisphere|Ocean    0.031154
#                                                                                      World|Northern Hemisphere|Land     0.029018
#                                                                                      World|Southern Hemisphere|Ocean    0.032503
#                                                                                      World|Southern Hemisphere|Land     0.027911
#
# time                                                                                                                  1767-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.033519
#                                                                                      World|Northern Hemisphere|Ocean    0.033979
#                                                                                      World|Northern Hemisphere|Land     0.031691
#                                                                                      World|Southern Hemisphere|Ocean    0.035423
#                                                                                      World|Southern Hemisphere|Land     0.030492
#
# time                                                                                                                  1768-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.036425
#                                                                                      World|Northern Hemisphere|Ocean    0.036917
#                                                                                      World|Northern Hemisphere|Land     0.034476
#                                                                                      World|Southern Hemisphere|Ocean    0.038457
#                                                                                      World|Southern Hemisphere|Land     0.033183
#
# time                                                                                                                  1769-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.039374
#                                                                                      World|Northern Hemisphere|Ocean    0.039898
#                                                                                      World|Northern Hemisphere|Land     0.037306
#                                                                                      World|Southern Hemisphere|Ocean    0.041534
#                                                                                      World|Southern Hemisphere|Land     0.035918
#
# time                                                                                                                  1770-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.042338
#                                                                                      World|Northern Hemisphere|Ocean    0.042894
#                                                                                      World|Northern Hemisphere|Land     0.040152
#                                                                                      World|Southern Hemisphere|Ocean    0.044625
#                                                                                      World|Southern Hemisphere|Land     0.038670
#
# time                                                                                                                  1771-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.045352
#                                                                                      World|Northern Hemisphere|Ocean    0.045941
#                                                                                      World|Northern Hemisphere|Land     0.043049
#                                                                                      World|Southern Hemisphere|Ocean    0.047766
#                                                                                      World|Southern Hemisphere|Land     0.041471
#
# time                                                                                                                  1772-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.048441
#                                                                                      World|Northern Hemisphere|Ocean    0.049062
#                                                                                      World|Northern Hemisphere|Land     0.046020
#                                                                                      World|Southern Hemisphere|Ocean    0.050982
#                                                                                      World|Southern Hemisphere|Land     0.044344
#
# time                                                                                                                  1773-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.051598
#                                                                                      World|Northern Hemisphere|Ocean    0.052251
#                                                                                      World|Northern Hemisphere|Land     0.049058
#                                                                                      World|Southern Hemisphere|Ocean    0.054267
#                                                                                      World|Southern Hemisphere|Land     0.047284
#
# time                                                                                                                  1774-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              0.054815
#                                                                                      World|Northern Hemisphere|Ocean    0.055501
#                                                                                      World|Northern Hemisphere|Land     0.052157
#                                                                                      World|Southern Hemisphere|Ocean    0.057612
#                                                                                      World|Southern Hemisphere|Land     0.050282
#
# time                                                                                                                  ...  \
# climate_model model scenario variable                           todo         unit    region                           ...
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                            ...
#                                                                                      World|Northern Hemisphere|Ocean  ...
#                                                                                      World|Northern Hemisphere|Land   ...
#                                                                                      World|Southern Hemisphere|Ocean  ...
#                                                                                      World|Southern Hemisphere|Land   ...
#
# time                                                                                                                  2091-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.091970
#                                                                                      World|Northern Hemisphere|Ocean    3.134965
#                                                                                      World|Northern Hemisphere|Land     2.989655
#                                                                                      World|Southern Hemisphere|Ocean    3.204502
#                                                                                      World|Southern Hemisphere|Land     2.869368
#
# time                                                                                                                  2092-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.083903
#                                                                                      World|Northern Hemisphere|Ocean    3.126769
#                                                                                      World|Northern Hemisphere|Land     2.981804
#                                                                                      World|Southern Hemisphere|Ocean    3.196197
#                                                                                      World|Southern Hemisphere|Land     2.861846
#
# time                                                                                                                  2093-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.075915
#                                                                                      World|Northern Hemisphere|Ocean    3.118651
#                                                                                      World|Northern Hemisphere|Land     2.974026
#                                                                                      World|Southern Hemisphere|Ocean    3.187978
#                                                                                      World|Southern Hemisphere|Land     2.854401
#
# time                                                                                                                  2094-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.068000
#                                                                                      World|Northern Hemisphere|Ocean    3.110604
#                                                                                      World|Northern Hemisphere|Land     2.966316
#                                                                                      World|Southern Hemisphere|Ocean    3.179838
#                                                                                      World|Southern Hemisphere|Land     2.847025
#
# time                                                                                                                  2095-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.060151
#                                                                                      World|Northern Hemisphere|Ocean    3.102621
#                                                                                      World|Northern Hemisphere|Land     2.958666
#                                                                                      World|Southern Hemisphere|Ocean    3.171769
#                                                                                      World|Southern Hemisphere|Land     2.839711
#
# time                                                                                                                  2096-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.052359
#                                                                                      World|Northern Hemisphere|Ocean    3.094694
#                                                                                      World|Northern Hemisphere|Land     2.951070
#                                                                                      World|Southern Hemisphere|Ocean    3.163762
#                                                                                      World|Southern Hemisphere|Land     2.832454
#
# time                                                                                                                  2097-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.044620
#                                                                                      World|Northern Hemisphere|Ocean    3.086819
#                                                                                      World|Northern Hemisphere|Land     2.943522
#                                                                                      World|Southern Hemisphere|Ocean    3.155811
#                                                                                      World|Southern Hemisphere|Land     2.825246
#
# time                                                                                                                  2098-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.036928
#                                                                                      World|Northern Hemisphere|Ocean    3.078989
#                                                                                      World|Northern Hemisphere|Land     2.936018
#                                                                                      World|Southern Hemisphere|Ocean    3.147912
#                                                                                      World|Southern Hemisphere|Land     2.818084
#
# time                                                                                                                  2099-01-01  \
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.029278
#                                                                                      World|Northern Hemisphere|Ocean    3.071201
#                                                                                      World|Northern Hemisphere|Land     2.928553
#                                                                                      World|Southern Hemisphere|Ocean    3.140057
#                                                                                      World|Southern Hemisphere|Land     2.810963
#
# time                                                                                                                  2100-01-01
# climate_model model scenario variable                           todo         unit    region
# MAGICC6       IMAGE RCP26    Radiative Forcing|Greenhouse Gases not_relevant W / m^2 World                              3.029278
#                                                                                      World|Northern Hemisphere|Ocean    3.071201
#                                                                                      World|Northern Hemisphere|Land     2.928553
#                                                                                      World|Southern Hemisphere|Ocean    3.140057
#                                                                                      World|Southern Hemisphere|Land     2.810963
#
# [5 rows x 336 columns]

# %% [markdown]
# Filter and plot results.

# %%
plt.figure(figsize=(16, 9))
results.filter(variable="*Concentrations|CO2",).line_plot(x="time");

# %%
plt.figure(figsize=(16, 9))
results.filter(variable="*Temperature*").line_plot(x="time");
