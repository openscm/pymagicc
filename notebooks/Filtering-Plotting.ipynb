# %% [markdown]
# # Filtering and plotting
#
# Here we provide a quick example of how to filter and plot with your data, making the most of the capability provided by pyam's IamDataFrame.

# %%
# NBVAL_IGNORE_OUTPUT
from pymagicc import MAGICC6
from pymagicc import rcp26

import matplotlib.pyplot as plt  
plt.style.use("bmh")

# %% [markdown]
# Run MAGICC6.

# %%
with MAGICC6() as magicc:
    results = magicc.run(rcp26)

# %%
# NBVAL_IGNORE_OUTPUT
# Note that row ordering may vary
results.head()
# Out:
#    model scenario                           region                   variable  \
# 0  IMAGE    RCP26                            World  Emissions|BC|MAGICC AFOLU
# 1  IMAGE    RCP26   World|Northern Hemisphere|Land  Emissions|BC|MAGICC AFOLU
# 2  IMAGE    RCP26  World|Northern Hemisphere|Ocean  Emissions|BC|MAGICC AFOLU
# 3  IMAGE    RCP26   World|Southern Hemisphere|Land  Emissions|BC|MAGICC AFOLU
# 4  IMAGE    RCP26  World|Southern Hemisphere|Ocean  Emissions|BC|MAGICC AFOLU
#
#          unit       time climate_model todo  value
# 0  Mt BC / yr 1765-07-12       MAGICC6  N/A    0.0
# 1  Mt BC / yr 1765-07-12       MAGICC6  N/A    0.0
# 2  Mt BC / yr 1765-07-12       MAGICC6  N/A    0.0
# 3  Mt BC / yr 1765-07-12       MAGICC6  N/A    0.0
# 4  Mt BC / yr 1765-07-12       MAGICC6  N/A    0.0

# %% [markdown]
# Filter and plot results.

# %%
results.filter(
    variable="*Concentrations|CO2",
).line_plot(x="time", figsize=(16, 9));

# %%
results.filter(
    variable="*Temperature*"
).line_plot(x="time", figsize=(16, 9));
